# %% [markdown]
# 📘 Two-Pointer Technique — Theory
#
# ->The Two-Pointer Technique is an algorithmic method where two variables (pointers) are used to scan through a data structure—usually an array  orlinked list—in a coordinated manner to solve problems efficiently.
#
# ->Instead of using nested loops (O(n²)), two pointers often allow solving problems in O(n) time.
#
# 🧠 Why Two Pointers Work
#
# ##Two pointers reduce unnecessary work by allowing you to:
#
# ->compare elements at two positions at the same time
#
# ->move towards the answer in a controlled way
#
# ->avoid scanning parts of the array multiple times
#
# ->It relies on the idea that moving one pointer forward or backward can help eliminate impossible solutions.
#
# ✨ When We Use Two Pointers
#
# ##Use it when:
#
# ->Array is sorted
# (ideal for pair/triplet sum, range checks, merging)
#
# ->Linked list traversal
# (cycle detection, middle node, deletion)
#
# ->Subarray/substring problems
# (window grows and shrinks)
#
# ->Optimization problems
# (max area, minimum length, valid window)
#
# 🔍 Pointer Behaviors (Core Logic)
#
# ##Two pointers can behave in several fixed patterns:
#
# 1. Opposite Direction
#
#    ->One pointer at start
#
#    ->One at end
#
#    ->Move toward each other
#        Used for:
#          ->Two Sum (sorted), 3Sum, Container With Most Water
#
# 2. Same Direction (Fast–Slow Pointers)
#
#    ->Both start together
#
#    ->One moves faster
#          Used for:
#            ->Cycle detection, middle of linked list, removing nth node
#
# 3. Sliding Window
#
#    ->Two pointers represent the start and end of a window
#
#    ->Right pointer expands
#
#    ->Left pointer shrinks
#           Used for:
#             ->Longest substring, subarray problems, frequency control
#
# 4. Dual Pointer Merge
#
#      ->Used to combine two sorted arrays/lists
#
#       ->Both pointers move only forward
#          Used for:
#             ->Merge sorted arrays, intersection of arrays
#
# 🔧 Key Principles
# ✔️ Move pointers based on conditions
#
#     ->Increase left pointer if value is too small
#
#     ->Decrease right pointer if value is too big
#
#     ->Expand window until condition breaks
#
#     ->Shrink window to restore validity
#
# ✔️ No pointer ever moves backward unnecessarily
#
#     ->This is what makes the technique linear time.
#
# ✔️ Works best on monotonic or structured data
#
#      ->Like sorted arrays or linked lists.
#
# 🚀 Advantages
#
#    ->Time-efficient: Most problems solved in O(n)
#
#    ->Space-efficient: Uses constant space
#
#     ->Avoids nested loops
#
# 🎓 In One Line (Interview Definition)
#
# Two Pointers is a technique where two indices traverse a data structure in a coordinated way—either together or from opposite ends—to reduce time complexity from O(n²) to O(n). It is mainly used in sorted arrays, linked lists, and sliding window problems.
